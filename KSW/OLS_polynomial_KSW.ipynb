# %% [markdown]
# # Fast Campus Data Science School 7th
#
# ## Regression Team Project
#
# ### Overview
# - Team: Team B-5 committer (김선웅, 이영인, 장승우)
# - Subject: New York City Taxi Trip Duration
# - Dataset: 2016 NYC Cab trip record data (by TLC)
# - Objective: Building a model that predicts the duration of each trip in New York City.
#
# #### Data fields
# - id - 각 운행별 고유 id
# - vendor_id - 운행별 각 택시 회사의 id
# - pickup_datetime - 승차 날짜/시각 (미터기 기록 시작)
# - dropoff_datetime - 하차 날짜/시각 (미터기 기록 종료)
# - passenger_count - 승객 수
# - pickup_longitude - 승차 위도
# - pickup_latitude - 승차 경도
# - dropoff_longitude - 하차 위도
# - dropoff_latitude - 하차 경도
# - store_and_fwd_flag - 운행 기록 서비 전송 전 차량 메모리 저장 여부 (Y: 저장/전송, N: 미저장/전송)
# - trip_duration - 운행 소요 시간 (초)

# %%
import numpy as np
import pandas as pd
import datetime as dt
import scipy as sp
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms 
import sklearn as sk

from patsy import dmatrix

import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

import platform
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/sunwoongkim/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
train = pd.read_csv("../dataset/train.csv", parse_dates=["pickup_datetime", "dropoff_datetime"])
print("Shape of Train Data: ", train.shape)
# Out:
# Shape of Train Data:  (1458644, 11)

# %%
train["pickup_month"] = train["pickup_datetime"].dt.month
train["pickup_weekday"] = train["pickup_datetime"].dt.weekday
train["pickup_hour"] = train["pickup_datetime"].dt.hour

train.shape
# Out:
# (1458644, 14)

# %%
working_day = [0, 1, 2, 3, 4] # Mon-Fri
train["working_day"] = train["pickup_weekday"].isin(working_day).astype(int)

# %%
train["store_and_fwd_flag"] = 1 * (train.store_and_fwd_flag.values == 'Y')

# %%
lat1, lng1, lat2, lng2 = (train['pickup_latitude'].values, train['pickup_longitude'].values, 
                          train['dropoff_latitude'].values, train['dropoff_longitude'].values)

# %%
def haversine_array(lat1, lng1, lat2, lng2):
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    AVG_EARTH_RADIUS = 6371  # in km
    lat = lat2 - lat1
    lng = lng2 - lng1
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d))
    return h

# %%
def bearing_array(lat1, lng1, lat2, lng2):
    lng_delta_rad = np.radians(lng2 - lng1)
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    y = np.sin(lng_delta_rad) * np.cos(lat2)
    x = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(lng_delta_rad)
    return (np.degrees(np.arctan2(y, x)) + 360) % 360 # from -180/180 to 0/360

# %%
train = train.assign(distance = haversine_array(lat1, lng1, lat2, lng2))
train = train.assign(bearing = bearing_array(lat1, lng1, lat2, lng2))

# %%
X_cols = [col for col in train.columns if col != "trip_duration"]
train_X0 = train[X_cols]
train_y = train[["trip_duration"]]

# %%
col_real = ["passenger_count", "distance", "bearing", "pickup_longitude", 
            "pickup_latitude", "dropoff_longitude", "dropoff_latitude"]

col_cats = [col for col in train.columns if col not in col_real]
for col in ["pickup_datetime", "dropoff_datetime", "id"]:
    col_cats.remove(col)
col_cats_nontime = ["vendor_id", "store_and_fwd_flag", "working_day"]

# %%
model = sm.OLS.from_formula("trip_duration ~ passenger_count + distance + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id) + C(store_and_fwd_flag)"
                            "+ C(working_day)", train)
result_01 = model.fit()

# %%
# print(result_01.summary())

# %%
result_sets = pd.DataFrame(columns=["R_squared", "Adj.R_squared", "AIC", "BIC", "P_fstatics", 
                                    "P_omnibus", "P_jb", "Cond_no", "changed"])

# %%
# 수정본 (Team B-5)
# 전역변수로 result_sets을 선언하고 사용

def storage(result, change) :
    
    summary = result.summary()
    table = summary.tables[2]
    
    p_omnibus = float(table.data[1][1])
    p_jb = float(table.data[2][3])
    
    put = {
        "R_squared" : result.rsquared,
        "Adj.R_squared": result.rsquared_adj,
        "AIC" : result.aic,
        "BIC" : result.bic,
        "P_fstatics" : result.f_pvalue,
        "P_omnibus" : p_omnibus,
        "P_jb" : p_jb,
        "Cond_no" : result.condition_number, 
        "changed" : change,
    }
    
    result_sets.loc[len(result_sets)] = put

# %% [markdown]
# ## 1. basic12와 동일 + pickup_hour 1~2

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                            "scale(bearing) + pickup_hour + I(pickup_hour ** 2) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_01 = model.fit()
print(result_01.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.590
# Model:                                 OLS   Adj. R-squared:                  0.590
# Method:                      Least Squares   F-statistic:                 2.626e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:57:14   Log-Likelihood:            -1.0858e+06
# No. Observations:                  1458644   AIC:                         2.172e+06
# Df Residuals:                      1458635   BIC:                         2.172e+06
# Df Model:                                8
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.7896      0.002   2326.193      0.000       4.786       4.794
# C(vendor_id)[T.2]           0.0218      0.001     25.819      0.000       0.020       0.023
# C(working_day)[T.1]         0.0964      0.001    102.353      0.000       0.095       0.098
# np.log1p(distance)          0.9661      0.001   1417.725      0.000       0.965       0.967
# pickup_month                0.0154      0.000     61.447      0.000       0.015       0.016
# scale(bearing)              0.0351      0.000     81.511      0.000       0.034       0.036
# pickup_hour                 0.0636      0.000    250.338      0.000       0.063       0.064
# I(pickup_hour ** 2)        -0.0024      1e-05   -235.900      0.000      -0.002      -0.002
# scale(dropoff_latitude)    -0.0280      0.000    -64.656      0.000      -0.029      -0.027
# ==============================================================================
# Omnibus:                   401885.269   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16594280.416
# Skew:                           0.606   Prob(JB):                         0.00
# Kurtosis:                      19.479   Cond. No.                     1.40e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_01, "basic12와 동일 + pickup_hour 1~2")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242        0.59024  2.171605e+06  2.171715e+06         0.0
#
#    P_omnibus  P_jb      Cond_no                        changed
# 0        0.0   0.0  1396.564907  basic12와 동일 + pickup_hour 1~2

# %% [markdown]
# ## 2. basic12와 동일 + pickup_hour 1~3

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                            "scale(bearing) + pickup_hour + I(pickup_hour ** 2) + I(pickup_hour ** 3) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_02 = model.fit()
print(result_02.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.594
# Model:                                 OLS   Adj. R-squared:                  0.594
# Method:                      Least Squares   F-statistic:                 2.368e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             12:02:19   Log-Likelihood:            -1.0797e+06
# No. Observations:                  1458644   AIC:                         2.159e+06
# Df Residuals:                      1458634   BIC:                         2.160e+06
# Df Model:                                9
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.8778      0.002   2217.001      0.000       4.873       4.882
# C(vendor_id)[T.2]           0.0216      0.001     25.630      0.000       0.020       0.023
# C(working_day)[T.1]         0.1056      0.001    112.110      0.000       0.104       0.107
# np.log1p(distance)          0.9678      0.001   1425.752      0.000       0.966       0.969
# pickup_month                0.0157      0.000     62.875      0.000       0.015       0.016
# scale(bearing)              0.0352      0.000     82.053      0.000       0.034       0.036
# pickup_hour                 0.0043      0.001      7.303      0.000       0.003       0.005
# I(pickup_hour ** 2)         0.0041   5.92e-05     68.935      0.000       0.004       0.004
# I(pickup_hour ** 3)        -0.0002   1.66e-06   -110.511      0.000      -0.000      -0.000
# scale(dropoff_latitude)    -0.0282      0.000    -65.235      0.000      -0.029      -0.027
# ==============================================================================
# Omnibus:                   406461.894   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17165093.783
# Skew:                           0.615   Prob(JB):                         0.00
# Kurtosis:                      19.761   Cond. No.                     2.98e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_02, "basic12와 동일 + pickup_hour 1~3")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
#
#    P_omnibus  P_jb       Cond_no                        changed
# 0        0.0   0.0   1396.564907  basic12와 동일 + pickup_hour 1~2
# 1        0.0   0.0  29799.564344  basic12와 동일 + pickup_hour 1~3

# %% [markdown]
# ## 3. basic12와 동일 + pickup_hour 1~4

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                            "scale(bearing) + pickup_hour + I(pickup_hour ** 2) + I(pickup_hour ** 3) + I(pickup_hour ** 4) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_03 = model.fit()
print(result_03.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.599
# Model:                                 OLS   Adj. R-squared:                  0.599
# Method:                      Least Squares   F-statistic:                 2.177e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             12:10:08   Log-Likelihood:            -1.0705e+06
# No. Observations:                  1458644   AIC:                         2.141e+06
# Df Residuals:                      1458633   BIC:                         2.141e+06
# Df Model:                               10
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.9855      0.002   2144.749      0.000       4.981       4.990
# C(vendor_id)[T.2]           0.0210      0.001     25.043      0.000       0.019       0.023
# C(working_day)[T.1]         0.1082      0.001    115.528      0.000       0.106       0.110
# np.log1p(distance)          0.9694      0.001   1436.932      0.000       0.968       0.971
# pickup_month                0.0155      0.000     62.344      0.000       0.015       0.016
# scale(bearing)              0.0344      0.000     80.793      0.000       0.034       0.035
# pickup_hour                -0.1413      0.001   -115.808      0.000      -0.144      -0.139
# I(pickup_hour ** 2)         0.0329      0.000    149.976      0.000       0.032       0.033
# I(pickup_hour ** 3)        -0.0021    1.4e-05   -148.544      0.000      -0.002      -0.002
# I(pickup_hour ** 4)      3.991e-05   2.93e-07    136.349      0.000    3.93e-05    4.05e-05
# scale(dropoff_latitude)    -0.0284      0.000    -66.273      0.000      -0.029      -0.028
# ==============================================================================
# Omnibus:                   411351.001   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18137666.356
# Skew:                           0.619   Prob(JB):                         0.00
# Kurtosis:                      20.231   Cond. No.                     6.75e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.75e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_03, "basic12와 동일 + pickup_hour 1~4")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                        changed
# 0        0.0   0.0    1396.564907  basic12와 동일 + pickup_hour 1~2
# 1        0.0   0.0   29799.564344  basic12와 동일 + pickup_hour 1~3
# 2        0.0   0.0  675016.119235  basic12와 동일 + pickup_hour 1~4

# %% [markdown]
# ## 4. basic12와 동일 + pickup_hour 1~5

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                            "scale(bearing) + pickup_hour + I(pickup_hour ** 2) + I(pickup_hour ** 3) + I(pickup_hour ** 4) + I(pickup_hour ** 5) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_04 = model.fit()
print(result_04.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.599
# Model:                                 OLS   Adj. R-squared:                  0.599
# Method:                      Least Squares   F-statistic:                 1.980e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             12:14:15   Log-Likelihood:            -1.0702e+06
# No. Observations:                  1458644   AIC:                         2.140e+06
# Df Residuals:                      1458632   BIC:                         2.141e+06
# Df Model:                               11
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.0027      0.002   2039.221      0.000       4.998       5.007
# C(vendor_id)[T.2]           0.0207      0.001     24.766      0.000       0.019       0.022
# C(working_day)[T.1]         0.1059      0.001    112.483      0.000       0.104       0.108
# np.log1p(distance)          0.9699      0.001   1437.098      0.000       0.969       0.971
# pickup_month                0.0155      0.000     62.259      0.000       0.015       0.016
# scale(bearing)              0.0342      0.000     80.183      0.000       0.033       0.035
# pickup_hour                -0.1789      0.002    -85.045      0.000      -0.183      -0.175
# I(pickup_hour ** 2)         0.0446      0.001     77.064      0.000       0.043       0.046
# I(pickup_hour ** 3)        -0.0034   6.24e-05    -54.654      0.000      -0.004      -0.003
# I(pickup_hour ** 4)         0.0001   2.91e-06     35.542      0.000    9.77e-05       0.000
# I(pickup_hour ** 5)     -1.074e-06    4.9e-08    -21.939      0.000   -1.17e-06   -9.78e-07
# scale(dropoff_latitude)    -0.0285      0.000    -66.536      0.000      -0.029      -0.028
# ==============================================================================
# Omnibus:                   412058.936   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18178907.063
# Skew:                           0.621   Prob(JB):                         0.00
# Kurtosis:                      20.250   Cond. No.                     1.69e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_04, "basic12와 동일 + pickup_hour 1~5")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
#
#    P_omnibus  P_jb       Cond_no                        changed
# 0        0.0   0.0  1.396565e+03  basic12와 동일 + pickup_hour 1~2
# 1        0.0   0.0  2.979956e+04  basic12와 동일 + pickup_hour 1~3
# 2        0.0   0.0  6.750161e+05  basic12와 동일 + pickup_hour 1~4
# 3        0.0   0.0  1.686887e+07  basic12와 동일 + pickup_hour 1~5

# %% [markdown]
# ## 5. basic12와 동일 + pickup_hour 1~4 scaled

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                            "scale(bearing) + scale(pickup_hour) + scale(I(pickup_hour**2)) + scale(I(pickup_hour**3)) + scale(I(pickup_hour**4) )+"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_05 = model.fit()
print(result_05.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.599
# Model:                                 OLS   Adj. R-squared:                  0.599
# Method:                      Least Squares   F-statistic:                 2.177e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             12:42:52   Log-Likelihood:            -1.0705e+06
# No. Observations:                  1458644   AIC:                         2.141e+06
# Df Residuals:                      1458633   BIC:                         2.141e+06
# Df Model:                               10
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      5.1079      0.002   3385.629      0.000       5.105       5.111
# C(vendor_id)[T.2]              0.0210      0.001     25.043      0.000       0.019       0.023
# C(working_day)[T.1]            0.1082      0.001    115.528      0.000       0.106       0.110
# np.log1p(distance)             0.9694      0.001   1436.932      0.000       0.968       0.971
# pickup_month                   0.0155      0.000     62.344      0.000       0.015       0.016
# scale(bearing)                 0.0344      0.000     80.793      0.000       0.034       0.035
# scale(pickup_hour)            -0.9042      0.008   -115.808      0.000      -0.919      -0.889
# scale(I(pickup_hour ** 2))     5.3107      0.035    149.976      0.000       5.241       5.380
# scale(I(pickup_hour ** 3))    -7.7485      0.052   -148.544      0.000      -7.851      -7.646
# scale(I(pickup_hour ** 4))     3.3477      0.025    136.349      0.000       3.300       3.396
# scale(dropoff_latitude)       -0.0284      0.000    -66.273      0.000      -0.029      -0.028
# ==============================================================================
# Omnibus:                   411351.001   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18137666.356
# Skew:                           0.619   Prob(JB):                         0.00
# Kurtosis:                      20.231   Cond. No.                         691.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_05, "basic12와 동일 + pickup_hour 1~4 scaled")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
#
#    P_omnibus  P_jb       Cond_no                               changed
# 0        0.0   0.0  1.396565e+03         basic12와 동일 + pickup_hour 1~2
# 1        0.0   0.0  2.979956e+04         basic12와 동일 + pickup_hour 1~3
# 2        0.0   0.0  6.750161e+05         basic12와 동일 + pickup_hour 1~4
# 3        0.0   0.0  1.686887e+07         basic12와 동일 + pickup_hour 1~5
# 4        0.0   0.0  6.907615e+02  basic12와 동일 + pickup_hour 1~4 scaled

# %% [markdown]
# ## 6. basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독립변수 모두 scaled

# %%
model = sm.OLS.from_formula("scale(np.log1p(trip_duration)) ~ scale(np.log1p(distance)) + scale(pickup_month) +" 
                            "scale(bearing) + scale(pickup_hour) + scale(I(pickup_hour**2)) + scale(I(pickup_hour**3)) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_06 = model.fit()
print(result_06.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     scale(np.log1p(trip_duration))   R-squared:                       0.594
# Model:                                        OLS   Adj. R-squared:                  0.594
# Method:                             Least Squares   F-statistic:                 2.368e+05
# Date:                            Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                                    12:49:56   Log-Likelihood:            -1.4130e+06
# No. Observations:                         1458644   AIC:                         2.826e+06
# Df Residuals:                             1458634   BIC:                         2.826e+06
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.1094      0.001    -95.261      0.000      -0.112      -0.107
# C(vendor_id)[T.2]              0.0271      0.001     25.630      0.000       0.025       0.029
# C(working_day)[T.1]            0.1327      0.001    112.110      0.000       0.130       0.135
# scale(np.log1p(distance))      0.7627      0.001   1425.752      0.000       0.762       0.764
# scale(pickup_month)            0.0332      0.001     62.875      0.000       0.032       0.034
# scale(bearing)                 0.0442      0.001     82.053      0.000       0.043       0.045
# scale(pickup_hour)             0.0349      0.005      7.303      0.000       0.026       0.044
# scale(I(pickup_hour ** 2))     0.8296      0.012     68.935      0.000       0.806       0.853
# scale(I(pickup_hour ** 3))    -0.8622      0.008   -110.511      0.000      -0.877      -0.847
# scale(dropoff_latitude)       -0.0354      0.001    -65.235      0.000      -0.036      -0.034
# ==============================================================================
# Omnibus:                   406461.894   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17165093.783
# Skew:                           0.615   Prob(JB):                         0.00
# Kurtosis:                      19.761   Cond. No.                         48.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_06, "basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독립변수 모두 scaled")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 5   0.593644       0.593642  2.825925e+06  2.826047e+06         0.0
#
#    P_omnibus  P_jb       Cond_no  \
# 0        0.0   0.0  1.396565e+03
# 1        0.0   0.0  2.979956e+04
# 2        0.0   0.0  6.750161e+05
# 3        0.0   0.0  1.686887e+07
# 4        0.0   0.0  6.907615e+02
# 5        0.0   0.0  4.851611e+01
#
#                                              changed
# 0                      basic12와 동일 + pickup_hour 1~2
# 1                      basic12와 동일 + pickup_hour 1~3
# 2                      basic12와 동일 + pickup_hour 1~4
# 3                      basic12와 동일 + pickup_hour 1~5
# 4               basic12와 동일 + pickup_hour 1~4 scaled
# 5  basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독...

# %% [markdown]
# ## 7. basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독립변수 모두 scaled

# %%
model = sm.OLS.from_formula("scale(np.log1p(trip_duration)) ~ scale(np.log1p(distance)) + scale(pickup_month) +" 
                            "scale(bearing) + scale(pickup_hour) + scale(I(pickup_hour**2))+"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_07 = model.fit()
print(result_07.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     scale(np.log1p(trip_duration))   R-squared:                       0.590
# Model:                                        OLS   Adj. R-squared:                  0.590
# Method:                             Least Squares   F-statistic:                 2.626e+05
# Date:                            Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                                    12:53:59   Log-Likelihood:            -1.4190e+06
# No. Observations:                         1458644   AIC:                         2.838e+06
# Df Residuals:                             1458635   BIC:                         2.838e+06
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.1013      0.001    -88.049      0.000      -0.104      -0.099
# C(vendor_id)[T.2]              0.0274      0.001     25.819      0.000       0.025       0.030
# C(working_day)[T.1]            0.1212      0.001    102.353      0.000       0.119       0.124
# scale(np.log1p(distance))      0.7614      0.001   1417.725      0.000       0.760       0.762
# scale(pickup_month)            0.0326      0.001     61.447      0.000       0.032       0.034
# scale(bearing)                 0.0441      0.001     81.511      0.000       0.043       0.045
# scale(pickup_hour)             0.5119      0.002    250.338      0.000       0.508       0.516
# scale(I(pickup_hour ** 2))    -0.4813      0.002   -235.900      0.000      -0.485      -0.477
# scale(dropoff_latitude)       -0.0352      0.001    -64.656      0.000      -0.036      -0.034
# ==============================================================================
# Omnibus:                   401885.269   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16594280.416
# Skew:                           0.606   Prob(JB):                         0.00
# Kurtosis:                      19.479   Cond. No.                         7.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_07, "basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독립변수 모두 scaled")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 5   0.593644       0.593642  2.825925e+06  2.826047e+06         0.0
# 6   0.590242       0.590240  2.838085e+06  2.838195e+06         0.0
#
#    P_omnibus  P_jb       Cond_no  \
# 0        0.0   0.0  1.396565e+03
# 1        0.0   0.0  2.979956e+04
# 2        0.0   0.0  6.750161e+05
# 3        0.0   0.0  1.686887e+07
# 4        0.0   0.0  6.907615e+02
# 5        0.0   0.0  4.851611e+01
# 6        0.0   0.0  7.614600e+00
#
#                                              changed
# 0                      basic12와 동일 + pickup_hour 1~2
# 1                      basic12와 동일 + pickup_hour 1~3
# 2                      basic12와 동일 + pickup_hour 1~4
# 3                      basic12와 동일 + pickup_hour 1~5
# 4               basic12와 동일 + pickup_hour 1~4 scaled
# 5  basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독...
# 6  basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독...

# %% [markdown]
# ## 8. basic12와 동일 + pickup_hour 2 scaled + 종속변수, 독립변수 모두 scaled

# %%
model = sm.OLS.from_formula("scale(np.log1p(trip_duration)) ~ scale(np.log1p(distance)) + scale(pickup_month) +" 
                            "scale(bearing) + scale(I(pickup_hour**2))+"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_08 = model.fit()
print(result_08.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     scale(np.log1p(trip_duration))   R-squared:                       0.573
# Model:                                        OLS   Adj. R-squared:                  0.573
# Method:                             Least Squares   F-statistic:                 2.792e+05
# Date:                            Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                                    12:56:01   Log-Likelihood:            -1.4497e+06
# No. Observations:                         1458644   AIC:                         2.899e+06
# Df Residuals:                             1458636   BIC:                         2.900e+06
# Df Model:                                       7
# Covariance Type:                        nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.1255      0.001   -107.178      0.000      -0.128      -0.123
# C(vendor_id)[T.2]              0.0283      0.001     26.045      0.000       0.026       0.030
# C(working_day)[T.1]            0.1544      0.001    128.503      0.000       0.152       0.157
# scale(np.log1p(distance))      0.7485      0.001   1370.983      0.000       0.747       0.750
# scale(pickup_month)            0.0315      0.001     58.190      0.000       0.030       0.033
# scale(bearing)                 0.0532      0.001     96.481      0.000       0.052       0.054
# scale(I(pickup_hour ** 2))     0.0118      0.001     21.837      0.000       0.011       0.013
# scale(dropoff_latitude)       -0.0265      0.001    -47.782      0.000      -0.028      -0.025
# ==============================================================================
# Omnibus:                   379204.189   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13566683.792
# Skew:                           0.569   Prob(JB):                         0.00
# Kurtosis:                      17.897   Cond. No.                         4.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_08, "basic12와 동일 + pickup_hour 2 scaled + 종속변수, 독립변수 모두 scaled")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 5   0.593644       0.593642  2.825925e+06  2.826047e+06         0.0
# 6   0.590242       0.590240  2.838085e+06  2.838195e+06         0.0
# 7   0.572637       0.572635  2.899444e+06  2.899541e+06         0.0
#
#    P_omnibus  P_jb       Cond_no  \
# 0        0.0   0.0  1.396565e+03
# 1        0.0   0.0  2.979956e+04
# 2        0.0   0.0  6.750161e+05
# 3        0.0   0.0  1.686887e+07
# 4        0.0   0.0  6.907615e+02
# 5        0.0   0.0  4.851611e+01
# 6        0.0   0.0  7.614600e+00
# 7        0.0   0.0  4.101156e+00
#
#                                              changed
# 0                      basic12와 동일 + pickup_hour 1~2
# 1                      basic12와 동일 + pickup_hour 1~3
# 2                      basic12와 동일 + pickup_hour 1~4
# 3                      basic12와 동일 + pickup_hour 1~5
# 4               basic12와 동일 + pickup_hour 1~4 scaled
# 5  basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독...
# 6  basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독...
# 7  basic12와 동일 + pickup_hour 2 scaled + 종속변수, 독립변...

# %% [markdown]
# ## 9. poly7 + bearing 1~2 scaled

# %%
model = sm.OLS.from_formula("scale(np.log1p(trip_duration)) ~ scale(np.log1p(distance)) + scale(pickup_month) +" 
                            "scale(bearing) + scale(I(bearing**2))+ scale(pickup_hour) + scale(I(pickup_hour**2))+"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_09 = model.fit()
print(result_09.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     scale(np.log1p(trip_duration))   R-squared:                       0.590
# Model:                                        OLS   Adj. R-squared:                  0.590
# Method:                             Least Squares   F-statistic:                 2.337e+05
# Date:                            Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                                    13:28:48   Log-Likelihood:            -1.4187e+06
# No. Observations:                         1458644   AIC:                         2.837e+06
# Df Residuals:                             1458634   BIC:                         2.837e+06
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.1010      0.001    -87.786      0.000      -0.103      -0.099
# C(vendor_id)[T.2]              0.0274      0.001     25.833      0.000       0.025       0.030
# C(working_day)[T.1]            0.1207      0.001    101.983      0.000       0.118       0.123
# scale(np.log1p(distance))      0.7616      0.001   1418.339      0.000       0.761       0.763
# scale(pickup_month)            0.0326      0.001     61.511      0.000       0.032       0.034
# scale(bearing)                 0.0984      0.002     48.248      0.000       0.094       0.102
# scale(I(bearing ** 2))        -0.0555      0.002    -27.626      0.000      -0.059      -0.052
# scale(pickup_hour)             0.5101      0.002    249.410      0.000       0.506       0.514
# scale(I(pickup_hour ** 2))    -0.4794      0.002   -234.925      0.000      -0.483      -0.475
# scale(dropoff_latitude)       -0.0298      0.001    -51.492      0.000      -0.031      -0.029
# ==============================================================================
# Omnibus:                   403591.221   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16418898.703
# Skew:                           0.617   Prob(JB):                         0.00
# Kurtosis:                      19.390   Cond. No.                         7.78
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_09, "poly7 + bearing 1~2 scaled")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 5   0.593644       0.593642  2.825925e+06  2.826047e+06         0.0
# 6   0.590242       0.590240  2.838085e+06  2.838195e+06         0.0
# 7   0.572637       0.572635  2.899444e+06  2.899541e+06         0.0
# 8   0.590456       0.590454  2.837324e+06  2.837446e+06         0.0
#
#    P_omnibus  P_jb       Cond_no  \
# 0        0.0   0.0  1.396565e+03
# 1        0.0   0.0  2.979956e+04
# 2        0.0   0.0  6.750161e+05
# 3        0.0   0.0  1.686887e+07
# 4        0.0   0.0  6.907615e+02
# 5        0.0   0.0  4.851611e+01
# 6        0.0   0.0  7.614600e+00
# 7        0.0   0.0  4.101156e+00
# 8        0.0   0.0  7.782751e+00
#
#                                              changed
# 0                      basic12와 동일 + pickup_hour 1~2
# 1                      basic12와 동일 + pickup_hour 1~3
# 2                      basic12와 동일 + pickup_hour 1~4
# 3                      basic12와 동일 + pickup_hour 1~5
# 4               basic12와 동일 + pickup_hour 1~4 scaled
# 5  basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독...
# 6  basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독...
# 7  basic12와 동일 + pickup_hour 2 scaled + 종속변수, 독립변...
# 8                         poly7 + bearing 1~2 scaled

# %% [markdown]
# ## 10. hour 2~4 scaled + bearing제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) +" 
                            "scale(I(pickup_hour**2)) + scale(I(pickup_hour**4))+"
                            "scale(dropoff_latitude) + C(working_day)", train)
result_10 = model.fit()
print(result_10.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.589
# Model:                                 OLS   Adj. R-squared:                  0.589
# Method:                      Least Squares   F-statistic:                 4.174e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             13:30:26   Log-Likelihood:            -1.0887e+06
# No. Observations:                  1458644   AIC:                         2.177e+06
# Df Residuals:                      1458638   BIC:                         2.177e+06
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      5.1765      0.001   4407.769      0.000       5.174       5.179
# C(working_day)[T.1]            0.1116      0.001    118.858      0.000       0.110       0.113
# np.log1p(distance)             0.9650      0.001   1415.112      0.000       0.964       0.966
# scale(I(pickup_hour ** 2))     0.4063      0.002    261.495      0.000       0.403       0.409
# scale(I(pickup_hour ** 4))    -0.4127      0.002   -265.622      0.000      -0.416      -0.410
# scale(dropoff_latitude)       -0.0341      0.000    -80.113      0.000      -0.035      -0.033
# ==============================================================================
# Omnibus:                   400829.786   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16931153.589
# Skew:                           0.594   Prob(JB):                         0.00
# Kurtosis:                      19.648   Cond. No.                         9.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_10, "hour 2~4 scaled + bearing제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.590242       0.590240  2.171605e+06  2.171715e+06         0.0
# 1   0.593644       0.593642  2.159445e+06  2.159567e+06         0.0
# 2   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 3   0.598891       0.598888  2.140495e+06  2.140641e+06         0.0
# 4   0.598758       0.598756  2.140974e+06  2.141108e+06         0.0
# 5   0.593644       0.593642  2.825925e+06  2.826047e+06         0.0
# 6   0.590242       0.590240  2.838085e+06  2.838195e+06         0.0
# 7   0.572637       0.572635  2.899444e+06  2.899541e+06         0.0
# 8   0.590456       0.590454  2.837324e+06  2.837446e+06         0.0
# 9   0.588629       0.588627  2.177331e+06  2.177404e+06         0.0
#
#    P_omnibus  P_jb       Cond_no  \
# 0        0.0   0.0  1.396565e+03
# 1        0.0   0.0  2.979956e+04
# 2        0.0   0.0  6.750161e+05
# 3        0.0   0.0  1.686887e+07
# 4        0.0   0.0  6.907615e+02
# 5        0.0   0.0  4.851611e+01
# 6        0.0   0.0  7.614600e+00
# 7        0.0   0.0  4.101156e+00
# 8        0.0   0.0  7.782751e+00
# 9        0.0   0.0  9.404033e+00
#
#                                              changed
# 0                      basic12와 동일 + pickup_hour 1~2
# 1                      basic12와 동일 + pickup_hour 1~3
# 2                      basic12와 동일 + pickup_hour 1~4
# 3                      basic12와 동일 + pickup_hour 1~5
# 4               basic12와 동일 + pickup_hour 1~4 scaled
# 5  basic12와 동일 + pickup_hour 1~3 scaled + 종속변수, 독...
# 6  basic12와 동일 + pickup_hour 1~2 scaled + 종속변수, 독...
# 7  basic12와 동일 + pickup_hour 2 scaled + 종속변수, 독립변...
# 8                         poly7 + bearing 1~2 scaled
# 9                        hour 2~4 scaled + bearing제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) +" 
                            "scale(I(pickup_hour**2)) + scale(I(pickup_hour**4))+"
                            "scale(dropoff_latitude) + C(working_day)", train)
result_10 = model.fit()
print(result_10.summary())

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet

# %%
from patsy import dmatrices

# %%
y, X = dmatrices("np.log1p(trip_duration) ~ np.log1p(distance) + pickup_month +" 
                "scale(bearing) + pickup_hour + I(pickup_hour ** 2) + I(pickup_hour ** 3) + I(pickup_hour ** 4) + I(pickup_hour ** 5) +"
                "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train, return_type = 'dataframe')

# %%
len(X.columns)
# Out:
# 12

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
x = diabetes.data

# %%
df = pd.DataFrame(x, columns=diabetes.feature_names)
len(df.columns)
# Out:
# 10

# %%
lasso_03 = Lasso(alpha=0.001).fit(X, y)

# %%
lasso_03.intercept_
# Out:
# array([ 4.8673271])

# %%
len(lasso_03.coef_)
# Out:
# 12

# %%
X.columns
# Out:
# Index(['Intercept', 'C(vendor_id)[T.2]', 'C(working_day)[T.1]',
#        'np.log1p(distance)', 'pickup_month', 'scale(bearing)', 'pickup_hour',
#        'I(pickup_hour ** 2)', 'I(pickup_hour ** 3)', 'I(pickup_hour ** 4)',
#        'I(pickup_hour ** 5)', 'scale(dropoff_latitude)'],
#       dtype='object')

# %%
alpha = np.logspace(-3, 1, 5)

data = []
for i, a in enumerate(alpha):
    lasso = Lasso(alpha=a).fit(X, y)
    data.append(pd.Series(np.hstack([lasso.intercept_, lasso.coef_])))
    
df_lasso = pd.DataFrame(data, index=alpha).T
df_lasso
# Out:
#           0.001         0.010         0.100         1.000         10.000
# 0   4.867327e+00  4.951657e+00  5.343202e+00  6.390808e+00  6.420976e+00
# 1   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2   1.757637e-02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 3   9.776648e-02  5.290414e-02  0.000000e+00  0.000000e+00  0.000000e+00
# 4   9.653265e-01  9.429446e-01  7.145666e-01  0.000000e+00  0.000000e+00
# 5   1.525644e-02  1.228032e-02  0.000000e+00  0.000000e+00  0.000000e+00
# 6   3.400180e-02  2.603340e-02  0.000000e+00  0.000000e+00  0.000000e+00
# 7   6.411375e-03  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8   4.986961e-03  6.047639e-03  5.338297e-03  0.000000e+00  0.000000e+00
# 9  -2.386925e-04 -2.881400e-04 -2.396156e-04  1.365154e-04  0.000000e+00
# 10 -3.203454e-06 -3.243706e-06 -4.375644e-06 -8.055980e-06  4.694908e-06
# 11  1.720533e-07  2.034999e-07  2.207033e-07  9.384122e-08 -2.088611e-07
# 12 -2.758216e-02 -2.119004e-02 -0.000000e+00 -0.000000e+00 -0.000000e+00

# %% [markdown]
# ## 2. 종속변수 log

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + distance + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id) + C(store_and_fwd_flag)"
                            "+ C(working_day)", train)
result_02 = model.fit()
print(result_02.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.344
# Model:                                 OLS   Adj. R-squared:                  0.344
# Method:                      Least Squares   F-statistic:                 5.895e+04
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             10:48:40   Log-Likelihood:            -1.4285e+06
# No. Observations:                  1458644   AIC:                         2.857e+06
# Df Residuals:                      1458630   BIC:                         2.857e+06
# Df Model:                               13
# Covariance Type:                 nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     29.8018      1.053     28.306      0.000      27.738      31.865
# C(vendor_id)[T.2]              0.0194      0.001     17.327      0.000       0.017       0.022
# C(store_and_fwd_flag)[T.1]     0.0078      0.007      1.085      0.278      -0.006       0.022
# C(working_day)[T.1]            0.1542      0.002     81.246      0.000       0.151       0.158
# passenger_count                0.0078      0.000     18.351      0.000       0.007       0.009
# distance                       0.1083      0.000    812.909      0.000       0.108       0.109
# bearing                        0.0004   6.06e-06     68.663      0.000       0.000       0.000
# pickup_month                   0.0179      0.000     56.462      0.000       0.017       0.019
# pickup_weekday                 0.0153      0.000     34.819      0.000       0.014       0.016
# pickup_hour                    0.0059   8.39e-05     70.564      0.000       0.006       0.006
# pickup_latitude               -0.6166      0.020    -31.603      0.000      -0.655      -0.578
# pickup_longitude              -1.5854      0.014   -110.020      0.000      -1.614      -1.557
# dropoff_latitude              -0.4566      0.018    -25.425      0.000      -0.492      -0.421
# dropoff_longitude              1.3199      0.014     94.641      0.000       1.293       1.347
# ==============================================================================
# Omnibus:                  2425723.069   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     126467027756.241
# Skew:                          -9.747   Prob(JB):                         0.00
# Kurtosis:                    1445.381   Cond. No.                     4.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_02, "종속변수 log")
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
#
#    P_omnibus  P_jb        Cond_no   changed
# 0        0.0   0.0  420621.388753     기본 모델
# 1        0.0   0.0  420621.388753  종속변수 log

# %% [markdown]
# ## 3. store_and_fwd_flag 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + distance + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id) + C(working_day)", train)
result_03 = model.fit()
print(result_03.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.344
# Model:                                 OLS   Adj. R-squared:                  0.344
# Method:                      Least Squares   F-statistic:                 6.386e+04
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             10:51:21   Log-Likelihood:            -1.4285e+06
# No. Observations:                  1458644   AIC:                         2.857e+06
# Df Residuals:                      1458631   BIC:                         2.857e+06
# Df Model:                               12
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              29.8101      1.053     28.315      0.000      27.747      31.874
# C(vendor_id)[T.2]       0.0193      0.001     17.295      0.000       0.017       0.022
# C(working_day)[T.1]     0.1542      0.002     81.249      0.000       0.151       0.158
# passenger_count         0.0078      0.000     18.353      0.000       0.007       0.009
# distance                0.1083      0.000    813.158      0.000       0.108       0.109
# bearing                 0.0004   6.06e-06     68.666      0.000       0.000       0.000
# pickup_month            0.0179      0.000     56.461      0.000       0.017       0.019
# pickup_weekday          0.0153      0.000     34.819      0.000       0.014       0.016
# pickup_hour             0.0059   8.39e-05     70.568      0.000       0.006       0.006
# pickup_latitude        -0.6167      0.020    -31.604      0.000      -0.655      -0.578
# pickup_longitude       -1.5854      0.014   -110.020      0.000      -1.614      -1.557
# dropoff_latitude       -0.4567      0.018    -25.431      0.000      -0.492      -0.422
# dropoff_longitude       1.3200      0.014     94.646      0.000       1.293       1.347
# ==============================================================================
# Omnibus:                  2425819.068   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     126499606778.865
# Skew:                          -9.748   Prob(JB):                         0.00
# Kurtosis:                    1445.567   Cond. No.                     4.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_03, "store_and_fwd_flag 제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거

# %% [markdown]
# ## 4. pickup_month 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + distance + bearing +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id) + C(working_day)", train)
result_04 = model.fit()
print(result_04.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.343
# Model:                                 OLS   Adj. R-squared:                  0.343
# Method:                      Least Squares   F-statistic:                 6.922e+04
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             10:52:27   Log-Likelihood:            -1.4301e+06
# No. Observations:                  1458644   AIC:                         2.860e+06
# Df Residuals:                      1458632   BIC:                         2.860e+06
# Df Model:                               11
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              29.8769      1.054     28.347      0.000      27.811      31.943
# C(vendor_id)[T.2]       0.0189      0.001     16.939      0.000       0.017       0.021
# C(working_day)[T.1]     0.1537      0.002     80.899      0.000       0.150       0.157
# passenger_count         0.0078      0.000     18.324      0.000       0.007       0.009
# distance                0.1084      0.000    813.212      0.000       0.108       0.109
# bearing                 0.0004   6.07e-06     68.343      0.000       0.000       0.000
# pickup_weekday          0.0149      0.000     34.050      0.000       0.014       0.016
# pickup_hour             0.0059    8.4e-05     70.261      0.000       0.006       0.006
# pickup_latitude        -0.6150      0.020    -31.484      0.000      -0.653      -0.577
# pickup_longitude       -1.5857      0.014   -109.920      0.000      -1.614      -1.557
# dropoff_latitude       -0.4572      0.018    -25.430      0.000      -0.492      -0.422
# dropoff_longitude       1.3209      0.014     94.611      0.000       1.294       1.348
# ==============================================================================
# Omnibus:                  2425399.228   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     126542595558.658
# Skew:                          -9.744   Prob(JB):                         0.00
# Kurtosis:                    1445.812   Cond. No.                     4.21e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_04, "pickup_month 제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611        pickup_month 제거

# %% [markdown]
# ## 5. 종속변수, distance log

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id) + C(working_day)", train)
result_05 = model.fit()
print(result_05.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.579
# Model:                                 OLS   Adj. R-squared:                  0.579
# Method:                      Least Squares   F-statistic:                 1.671e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             10:57:53   Log-Likelihood:            -1.1058e+06
# No. Observations:                  1458644   AIC:                         2.212e+06
# Df Residuals:                      1458631   BIC:                         2.212e+06
# Df Model:                               12
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -31.9180      0.838    -38.073      0.000     -33.561     -30.275
# C(vendor_id)[T.2]       0.0175      0.001     19.604      0.000       0.016       0.019
# C(working_day)[T.1]     0.1676      0.002    110.148      0.000       0.165       0.171
# passenger_count         0.0066      0.000     19.499      0.000       0.006       0.007
# np.log1p(distance)      0.9711      0.001   1356.864      0.000       0.970       0.973
# bearing                 0.0006   4.86e-06    113.447      0.000       0.001       0.001
# pickup_month            0.0151      0.000     59.491      0.000       0.015       0.016
# pickup_weekday          0.0145      0.000     41.363      0.000       0.014       0.015
# pickup_hour             0.0060   6.72e-05     88.573      0.000       0.006       0.006
# pickup_latitude         0.3106      0.016     19.831      0.000       0.280       0.341
# pickup_longitude       -0.9325      0.011    -82.346      0.000      -0.955      -0.910
# dropoff_latitude       -0.5125      0.014    -35.673      0.000      -0.541      -0.484
# dropoff_longitude       0.3243      0.011     29.172      0.000       0.302       0.346
# ==============================================================================
# Omnibus:                   441820.450   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         47469433.733
# Skew:                           0.422   Prob(JB):                         0.00
# Kurtosis:                      30.934   Cond. No.                     4.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_05, "종속변수, distance log")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611        pickup_month 제거
# 4        0.0   0.0  417822.233319     종속변수, distance log

# %% [markdown]
# ## 6. 위경도 scale

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_latitude) + scale(dropoff_longitude) + C(vendor_id) + C(working_day)", train)
result_06 = model.fit()
print(result_06.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.579
# Model:                                 OLS   Adj. R-squared:                  0.579
# Method:                      Least Squares   F-statistic:                 1.671e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:09:06   Log-Likelihood:            -1.1058e+06
# No. Observations:                  1458644   AIC:                         2.212e+06
# Df Residuals:                      1458631   BIC:                         2.212e+06
# Df Model:                               12
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    4.8453      0.003   1729.523      0.000       4.840       4.851
# C(vendor_id)[T.2]            0.0175      0.001     19.604      0.000       0.016       0.019
# C(working_day)[T.1]          0.1676      0.002    110.148      0.000       0.165       0.171
# passenger_count              0.0066      0.000     19.499      0.000       0.006       0.007
# np.log1p(distance)           0.9711      0.001   1356.864      0.000       0.970       0.973
# bearing                      0.0006   4.86e-06    113.447      0.000       0.001       0.001
# pickup_month                 0.0151      0.000     59.491      0.000       0.015       0.016
# pickup_weekday               0.0145      0.000     41.363      0.000       0.014       0.015
# pickup_hour                  0.0060   6.72e-05     88.573      0.000       0.006       0.006
# scale(pickup_latitude)       0.0102      0.001     19.831      0.000       0.009       0.011
# scale(pickup_longitude)     -0.0661      0.001    -82.346      0.000      -0.068      -0.065
# scale(dropoff_latitude)     -0.0184      0.001    -35.673      0.000      -0.019      -0.017
# scale(dropoff_longitude)     0.0229      0.001     29.172      0.000       0.021       0.024
# ==============================================================================
# Omnibus:                   441820.450   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         47469433.733
# Skew:                           0.422   Prob(JB):                         0.00
# Kurtosis:                      30.934   Cond. No.                     1.32e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_06, "위경도 scale")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611        pickup_month 제거
# 4        0.0   0.0  417822.233319     종속변수, distance log
# 5        0.0   0.0    1322.093218              위경도 scale

# %% [markdown]
# ## dropoff_longitude 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + C(vendor_id) + C(working_day)", train)
result_07 = model.fit()
print(result_07.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.579
# Model:                                 OLS   Adj. R-squared:                  0.579
# Method:                      Least Squares   F-statistic:                 1.821e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:20:19   Log-Likelihood:            -1.1063e+06
# No. Observations:                  1458644   AIC:                         2.213e+06
# Df Residuals:                      1458632   BIC:                         2.213e+06
# Df Model:                               11
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             -37.5568      0.816    -46.026      0.000     -39.156     -35.957
# C(vendor_id)[T.2]       0.0174      0.001     19.424      0.000       0.016       0.019
# C(working_day)[T.1]     0.1677      0.002    110.148      0.000       0.165       0.171
# passenger_count         0.0066      0.000     19.471      0.000       0.006       0.007
# np.log1p(distance)      0.9708      0.001   1356.196      0.000       0.969       0.972
# bearing                 0.0005   4.32e-06    112.558      0.000       0.000       0.000
# pickup_month            0.0151      0.000     59.470      0.000       0.015       0.016
# pickup_weekday          0.0147      0.000     41.719      0.000       0.014       0.015
# pickup_hour             0.0059   6.72e-05     87.184      0.000       0.006       0.006
# pickup_latitude         0.4102      0.015     26.830      0.000       0.380       0.440
# pickup_longitude       -0.6595      0.006   -103.388      0.000      -0.672      -0.647
# dropoff_latitude       -0.5666      0.014    -39.761      0.000      -0.595      -0.539
# ==============================================================================
# Omnibus:                   453292.839   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         64650683.783
# Skew:                           0.360   Prob(JB):                         0.00
# Kurtosis:                      35.607   Cond. No.                     3.86e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.86e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_07, "dropoff_longitude 제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6   0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611        pickup_month 제거
# 4        0.0   0.0  417822.233319     종속변수, distance log
# 5        0.0   0.0    1322.093218              위경도 scale
# 6        0.0   0.0  386395.429960   dropoff_longitude 제거

# %% [markdown]
# ## 8. pickup_longitude 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + "
                            "dropoff_latitude + C(vendor_id) + C(working_day)", train)
result_08 = model.fit()
print(result_08.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.575
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                 1.977e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:25:32   Log-Likelihood:            -1.1116e+06
# No. Observations:                  1458644   AIC:                         2.223e+06
# Df Residuals:                      1458633   BIC:                         2.223e+06
# Df Model:                               10
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              19.3108      0.605     31.921      0.000      18.125      20.497
# C(vendor_id)[T.2]       0.0169      0.001     18.858      0.000       0.015       0.019
# C(working_day)[T.1]     0.1674      0.002    109.580      0.000       0.164       0.170
# passenger_count         0.0067      0.000     19.523      0.000       0.006       0.007
# np.log1p(distance)      0.9538      0.001   1364.233      0.000       0.952       0.955
# bearing                 0.0004   4.23e-06     91.615      0.000       0.000       0.000
# pickup_month            0.0151      0.000     59.158      0.000       0.015       0.016
# pickup_weekday          0.0150      0.000     42.437      0.000       0.014       0.016
# pickup_hour             0.0058   6.74e-05     85.953      0.000       0.006       0.006
# pickup_latitude         0.4477      0.015     29.185      0.000       0.418       0.478
# dropoff_latitude       -0.8015      0.014    -56.769      0.000      -0.829      -0.774
# ==============================================================================
# Omnibus:                   385755.769   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14041126.942
# Skew:                           0.588   Prob(JB):                         0.00
# Kurtosis:                      18.154   Cond. No.                     2.71e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.71e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_08, "pickup_longitude 제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6   0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
# 7   0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                changed
# 0        0.0   0.0  420621.388753                  기본 모델
# 1        0.0   0.0  420621.388753               종속변수 log
# 2        0.0   0.0  420610.107281  store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611        pickup_month 제거
# 4        0.0   0.0  417822.233319     종속변수, distance log
# 5        0.0   0.0    1322.093218              위경도 scale
# 6        0.0   0.0  386395.429960   dropoff_longitude 제거
# 7        0.0   0.0  270700.547803    pickup_longitude 제거

# %% [markdown]
# ## 9. scale(pickup_latitude, dropoff_latitude)

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour + scale(pickup_latitude) + "
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_09 = model.fit()
print(result_09.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.575
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                 1.977e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:28:01   Log-Likelihood:            -1.1116e+06
# No. Observations:                  1458644   AIC:                         2.223e+06
# Df Residuals:                      1458633   BIC:                         2.223e+06
# Df Model:                               10
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.8936      0.003   1771.587      0.000       4.888       4.899
# C(vendor_id)[T.2]           0.0169      0.001     18.858      0.000       0.015       0.019
# C(working_day)[T.1]         0.1674      0.002    109.580      0.000       0.164       0.170
# passenger_count             0.0067      0.000     19.523      0.000       0.006       0.007
# np.log1p(distance)          0.9538      0.001   1364.233      0.000       0.952       0.955
# bearing                     0.0004   4.23e-06     91.615      0.000       0.000       0.000
# pickup_month                0.0151      0.000     59.158      0.000       0.015       0.016
# pickup_weekday              0.0150      0.000     42.437      0.000       0.014       0.016
# pickup_hour                 0.0058   6.74e-05     85.953      0.000       0.006       0.006
# scale(pickup_latitude)      0.0147      0.001     29.185      0.000       0.014       0.016
# scale(dropoff_latitude)    -0.0288      0.001    -56.769      0.000      -0.030      -0.028
# ==============================================================================
# Omnibus:                   385755.769   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         14041126.942
# Skew:                           0.588   Prob(JB):                         0.00
# Kurtosis:                      18.154   Cond. No.                     1.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_09, "pickup_latitude, dropoff_latitude scale")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6   0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
# 7   0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 8   0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                                  changed
# 0        0.0   0.0  420621.388753                                    기본 모델
# 1        0.0   0.0  420621.388753                                 종속변수 log
# 2        0.0   0.0  420610.107281                    store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611                          pickup_month 제거
# 4        0.0   0.0  417822.233319                       종속변수, distance log
# 5        0.0   0.0    1322.093218                                위경도 scale
# 6        0.0   0.0  386395.429960                     dropoff_longitude 제거
# 7        0.0   0.0  270700.547803                      pickup_longitude 제거
# 8        0.0   0.0    1302.762270  pickup_latitude, dropoff_latitude scale

# %% [markdown]
# ## 10. pickup_latitude 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ passenger_count + np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_10 = model.fit()
print(result_10.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.575
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                 2.195e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:39:18   Log-Likelihood:            -1.1120e+06
# No. Observations:                  1458644   AIC:                         2.224e+06
# Df Residuals:                      1458634   BIC:                         2.224e+06
# Df Model:                                9
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.8947      0.003   1771.694      0.000       4.889       4.900
# C(vendor_id)[T.2]           0.0170      0.001     18.879      0.000       0.015       0.019
# C(working_day)[T.1]         0.1680      0.002    109.976      0.000       0.165       0.171
# passenger_count             0.0066      0.000     19.453      0.000       0.006       0.007
# np.log1p(distance)          0.9506      0.001   1376.358      0.000       0.949       0.952
# bearing                     0.0004    4.2e-06     96.002      0.000       0.000       0.000
# pickup_month                0.0151      0.000     59.207      0.000       0.015       0.016
# pickup_weekday              0.0150      0.000     42.437      0.000       0.014       0.016
# pickup_hour                 0.0058   6.74e-05     85.881      0.000       0.006       0.006
# scale(dropoff_latitude)    -0.0214      0.000    -48.695      0.000      -0.022      -0.021
# ==============================================================================
# Omnibus:                   384194.430   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13889532.938
# Skew:                           0.584   Prob(JB):                         0.00
# Kurtosis:                      18.072   Cond. No.                     1.30e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_10, "9와 동일 + pickup_latitude 제거")

# %%
result_sets
# Out:
#    R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0   0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1   0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2   0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3   0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5   0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6   0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
# 7   0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 8   0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 9   0.575247       0.575244  2.224034e+06  2.224156e+06         0.0
#
#    P_omnibus  P_jb        Cond_no                                  changed
# 0        0.0   0.0  420621.388753                                    기본 모델
# 1        0.0   0.0  420621.388753                                 종속변수 log
# 2        0.0   0.0  420610.107281                    store_and_fwd_flag 제거
# 3        0.0   0.0  420562.767611                          pickup_month 제거
# 4        0.0   0.0  417822.233319                       종속변수, distance log
# 5        0.0   0.0    1322.093218                                위경도 scale
# 6        0.0   0.0  386395.429960                     dropoff_longitude 제거
# 7        0.0   0.0  270700.547803                      pickup_longitude 제거
# 8        0.0   0.0    1302.762270  pickup_latitude, dropoff_latitude scale
# 9        0.0   0.0    1302.680917               9와 동일 + pickup_latitude 제거

# %% [markdown]
# ## 11. passenger_count 제거

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + bearing + pickup_month +" 
                            "pickup_weekday + pickup_hour +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_11 = model.fit()
print(result_11.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.575
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                 2.468e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:40:40   Log-Likelihood:            -1.1122e+06
# No. Observations:                  1458644   AIC:                         2.224e+06
# Df Residuals:                      1458635   BIC:                         2.225e+06
# Df Model:                                8
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   4.9030      0.003   1795.697      0.000       4.898       4.908
# C(vendor_id)[T.2]           0.0220      0.001     25.542      0.000       0.020       0.024
# C(working_day)[T.1]         0.1676      0.002    109.701      0.000       0.165       0.171
# np.log1p(distance)          0.9507      0.001   1376.391      0.000       0.949       0.952
# bearing                     0.0004    4.2e-06     95.975      0.000       0.000       0.000
# pickup_month                0.0151      0.000     59.196      0.000       0.015       0.016
# pickup_weekday              0.0150      0.000     42.541      0.000       0.014       0.016
# pickup_hour                 0.0058   6.74e-05     86.062      0.000       0.006       0.006
# scale(dropoff_latitude)    -0.0215      0.000    -48.741      0.000      -0.022      -0.021
# ==============================================================================
# Omnibus:                   384071.114   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13893273.453
# Skew:                           0.583   Prob(JB):                         0.00
# Kurtosis:                      18.074   Cond. No.                     1.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
storage(result_11, "passenger_count 제거")

# %%
result_sets
# Out:
#     R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0    0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1    0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2    0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3    0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4    0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5    0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6    0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
# 7    0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 8    0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 9    0.575247       0.575244  2.224034e+06  2.224156e+06         0.0
# 10   0.575136       0.575134  2.224410e+06  2.224520e+06         0.0
#
#     P_omnibus  P_jb        Cond_no                                  changed
# 0         0.0   0.0  420621.388753                                    기본 모델
# 1         0.0   0.0  420621.388753                                 종속변수 log
# 2         0.0   0.0  420610.107281                    store_and_fwd_flag 제거
# 3         0.0   0.0  420562.767611                          pickup_month 제거
# 4         0.0   0.0  417822.233319                       종속변수, distance log
# 5         0.0   0.0    1322.093218                                위경도 scale
# 6         0.0   0.0  386395.429960                     dropoff_longitude 제거
# 7         0.0   0.0  270700.547803                      pickup_longitude 제거
# 8         0.0   0.0    1302.762270  pickup_latitude, dropoff_latitude scale
# 9         0.0   0.0    1302.680917               9와 동일 + pickup_latitude 제거
# 10        0.0   0.0    1291.931040                       passenger_count 제거

# %% [markdown]
# ## 12. bearing, 시간 scale

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + scale(bearing) + scale(pickup_month) +" 
                            "scale(pickup_weekday) + scale(pickup_hour) +"
                            "scale(dropoff_latitude) + C(vendor_id) + C(working_day)", train)
result_12 = model.fit()
print(result_12.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.575
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                 2.468e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             11:43:20   Log-Likelihood:            -1.1122e+06
# No. Observations:                  1458644   AIC:                         2.224e+06
# Df Residuals:                      1458635   BIC:                         2.225e+06
# Df Model:                                8
# Covariance Type:                 nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.1427      0.002   3349.880      0.000       5.140       5.146
# C(vendor_id)[T.2]           0.0220      0.001     25.542      0.000       0.020       0.024
# C(working_day)[T.1]         0.1676      0.002    109.701      0.000       0.165       0.171
# np.log1p(distance)          0.9507      0.001   1376.391      0.000       0.949       0.952
# scale(bearing)              0.0420      0.000     95.975      0.000       0.041       0.043
# scale(pickup_month)         0.0254      0.000     59.196      0.000       0.025       0.026
# scale(pickup_weekday)       0.0293      0.001     42.541      0.000       0.028       0.031
# scale(pickup_hour)          0.0371      0.000     86.062      0.000       0.036       0.038
# scale(dropoff_latitude)    -0.0215      0.000    -48.741      0.000      -0.022      -0.021
# ==============================================================================
# Omnibus:                   384071.114   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         13893273.453
# Skew:                           0.583   Prob(JB):                         0.00
# Kurtosis:                      18.074   Cond. No.                         9.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
storage(result_12, "bearing, 시간 scale")

# %%
result_sets
# Out:
#     R_squared  Adj.R_squared           AIC           BIC  P_fstatics  \
# 0    0.009621       0.009612  2.910783e+07  2.910800e+07         0.0
# 1    0.344416       0.344411  2.857118e+06  2.857289e+06         0.0
# 2    0.344416       0.344410  2.857118e+06  2.857276e+06         0.0
# 3    0.342983       0.342978  2.860300e+06  2.860446e+06         0.0
# 4    0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 5    0.578828       0.578825  2.211688e+06  2.211846e+06         0.0
# 6    0.578583       0.578580  2.212536e+06  2.212683e+06         0.0
# 7    0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 8    0.575494       0.575492  2.223185e+06  2.223319e+06         0.0
# 9    0.575247       0.575244  2.224034e+06  2.224156e+06         0.0
# 10   0.575136       0.575134  2.224410e+06  2.224520e+06         0.0
# 11   0.575136       0.575134  2.224410e+06  2.224520e+06         0.0
#
#     P_omnibus  P_jb        Cond_no                                  changed
# 0         0.0   0.0  420621.388753                                    기본 모델
# 1         0.0   0.0  420621.388753                                 종속변수 log
# 2         0.0   0.0  420610.107281                    store_and_fwd_flag 제거
# 3         0.0   0.0  420562.767611                          pickup_month 제거
# 4         0.0   0.0  417822.233319                       종속변수, distance log
# 5         0.0   0.0    1322.093218                                위경도 scale
# 6         0.0   0.0  386395.429960                     dropoff_longitude 제거
# 7         0.0   0.0  270700.547803                      pickup_longitude 제거
# 8         0.0   0.0    1302.762270  pickup_latitude, dropoff_latitude scale
# 9         0.0   0.0    1302.680917               9와 동일 + pickup_latitude 제거
# 10        0.0   0.0    1291.931040                       passenger_count 제거
# 11        0.0   0.0       9.247934                        bearing, 시간 scale

# %% [markdown]
# ## 5. vendor_id 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ passenger_count + distance + bearing +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(working_day)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1364.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:13:00   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458633   BIC:                         2.911e+07
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            9.643e+04   8518.305     11.321      0.000    7.97e+04    1.13e+05
# C(working_day)[T.1]   118.7804     15.360      7.733      0.000      88.676     148.885
# passenger_count        30.1051      3.286      9.161      0.000      23.664      36.546
# distance              112.5890      1.077    104.535      0.000     110.478     114.700
# bearing                 0.3752      0.049      7.654      0.000       0.279       0.471
# pickup_weekday         17.3834      3.547      4.900      0.000      10.431      24.336
# pickup_hour             4.1125      0.679      6.061      0.000       2.783       5.442
# pickup_latitude     -1606.7954    157.873    -10.178      0.000   -1916.222   -1297.369
# pickup_longitude     -417.6435    116.592     -3.582      0.000    -646.159    -189.128
# dropoff_latitude     -280.1924    145.311     -1.928      0.054    -564.997       4.612
# dropoff_longitude     678.1112    112.837      6.010      0.000     456.954     899.269
# ================================================================================
# Omnibus:                  8313077.705   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2319804466653168.500
# Skew:                         347.487   Prob(JB):                           0.00
# Kurtosis:                  195371.215   Cond. No.                       4.21e+05
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 5. working_day 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ passenger_count + distance + bearing +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1407.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:15:02   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458633   BIC:                         2.911e+07
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           9.63e+04   8516.783     11.307      0.000    7.96e+04    1.13e+05
# C(vendor_id)[T.2]   199.1061      9.035     22.037      0.000     181.398     216.814
# passenger_count       8.0244      3.430      2.340      0.019       1.302      14.747
# distance            112.4622      1.077    104.432      0.000     110.352     114.573
# bearing               0.3743      0.049      7.637      0.000       0.278       0.470
# pickup_weekday       -3.7598      2.219     -1.694      0.090      -8.109       0.589
# pickup_hour           4.2269      0.678      6.235      0.000       2.898       5.556
# pickup_latitude   -1596.6422    157.834    -10.116      0.000   -1905.991   -1287.293
# pickup_longitude   -436.3264    116.578     -3.743      0.000    -664.815    -207.838
# dropoff_latitude   -292.5455    145.291     -2.014      0.044    -577.311      -7.780
# dropoff_longitude   692.7134    112.823      6.140      0.000     471.585     913.842
# ================================================================================
# Omnibus:                  8314093.519   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322907515767978.500
# Skew:                         347.647   Prob(JB):                           0.00
# Kurtosis:                  195501.837   Cond. No.                       4.21e+05
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 6. passenger_count 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ distance + bearing +" 
                            "pickup_weekday + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1562.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:18:01   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458634   BIC:                         2.911e+07
# Df Model:                           9
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          9.634e+04   8516.776     11.312      0.000    7.97e+04    1.13e+05
# C(vendor_id)[T.2]   205.1799      8.654     23.710      0.000     188.219     222.141
# distance            112.4808      1.077    104.452      0.000     110.370     114.591
# bearing               0.3743      0.049      7.636      0.000       0.278       0.470
# pickup_weekday       -3.6229      2.218     -1.633      0.102      -7.970       0.725
# pickup_hour           4.2413      0.678      6.256      0.000       2.913       5.570
# pickup_latitude   -1597.5271    157.834    -10.122      0.000   -1906.876   -1288.179
# pickup_longitude   -436.5143    116.578     -3.744      0.000    -665.003    -208.026
# dropoff_latitude   -292.8837    145.291     -2.016      0.044    -577.649      -8.118
# dropoff_longitude   692.6836    112.823      6.140      0.000     471.555     913.813
# ================================================================================
# Omnibus:                  8314079.180   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322863098822995.000
# Skew:                         347.645   Prob(JB):                           0.00
# Kurtosis:                  195499.968   Cond. No.                       4.21e+05
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.21e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## pickup_weekday 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ distance + bearing + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_latitude + dropoff_longitude + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1757.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:19:20   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458635   BIC:                         2.911e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          9.612e+04   8515.628     11.287      0.000    7.94e+04    1.13e+05
# C(vendor_id)[T.2]   205.1462      8.654     23.706      0.000     188.185     222.107
# distance            112.4703      1.077    104.444      0.000     110.360     114.581
# bearing               0.3740      0.049      7.631      0.000       0.278       0.470
# pickup_hour           4.3327      0.676      6.413      0.000       3.008       5.657
# pickup_latitude   -1591.7079    157.793    -10.087      0.000   -1900.978   -1282.438
# pickup_longitude   -432.1288    116.547     -3.708      0.000    -660.557    -203.701
# dropoff_latitude   -291.7585    145.290     -2.008      0.045    -576.521      -6.996
# dropoff_longitude   689.1946    112.803      6.110      0.000     468.105     910.284
# ================================================================================
# Omnibus:                  8314066.340   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322823040899635.000
# Skew:                         347.643   Prob(JB):                           0.00
# Kurtosis:                  195498.282   Cond. No.                       4.20e+05
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.2e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## dropoff_longitude 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ distance + bearing + pickup_hour + pickup_latitude + pickup_longitude +"
                            "dropoff_longitude + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2008.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:20:34   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458636   BIC:                         2.911e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          8.946e+04   7843.634     11.405      0.000    7.41e+04    1.05e+05
# C(vendor_id)[T.2]   205.0814      8.654     23.698      0.000     188.120     222.043
# distance            112.6683      1.072    105.069      0.000     110.567     114.770
# bearing               0.4017      0.047      8.538      0.000       0.309       0.494
# pickup_hour           4.3298      0.676      6.409      0.000       3.006       5.654
# pickup_latitude   -1750.7865    136.467    -12.829      0.000   -2018.258   -1483.315
# pickup_longitude   -480.0237    114.080     -4.208      0.000    -703.618    -256.430
# dropoff_longitude   720.2421    111.738      6.446      0.000     501.239     939.245
# ================================================================================
# Omnibus:                  8314034.686   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322728224630793.500
# Skew:                         347.638   Prob(JB):                           0.00
# Kurtosis:                  195494.292   Cond. No.                       3.81e+05
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.81e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 위치 데이터에 scale

# %%
model = sm.OLS.from_formula("trip_duration ~ distance + bearing + pickup_hour + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + scale(dropoff_latitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1757.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:22:13   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458635   BIC:                         2.911e+07
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  346.4213     14.185     24.422      0.000     318.620     374.223
# C(vendor_id)[T.2]          205.1462      8.654     23.706      0.000     188.185     222.107
# distance                   112.4703      1.077    104.444      0.000     110.360     114.581
# bearing                      0.3740      0.049      7.631      0.000       0.278       0.470
# pickup_hour                  4.3327      0.676      6.413      0.000       3.008       5.657
# scale(pickup_latitude)     -52.3372      5.188    -10.087      0.000     -62.506     -42.168
# scale(pickup_longitude)    -30.6387      8.263     -3.708      0.000     -46.835     -14.443
# scale(dropoff_longitude)    48.6869      7.969      6.110      0.000      33.068      64.305
# scale(dropoff_latitude)    -10.4714      5.215     -2.008      0.045     -20.692      -0.251
# ================================================================================
# Omnibus:                  8314066.340   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322823040899633.500
# Skew:                         347.643   Prob(JB):                           0.00
# Kurtosis:                  195498.282   Cond. No.                           665.
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## scale(dropoff_latitude) 제거

# %%
model = sm.OLS.from_formula("trip_duration ~ distance + bearing + pickup_hour + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          trip_duration   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2008.
# Date:                Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                        23:23:44   Log-Likelihood:            -1.4554e+07
# No. Observations:             1458644   AIC:                         2.911e+07
# Df Residuals:                 1458636   BIC:                         2.911e+07
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  341.5763     13.978     24.437      0.000     314.180     368.973
# C(vendor_id)[T.2]          205.0814      8.654     23.698      0.000     188.120     222.043
# distance                   112.6683      1.072    105.069      0.000     110.567     114.770
# bearing                      0.4017      0.047      8.538      0.000       0.309       0.494
# pickup_hour                  4.3298      0.676      6.409      0.000       3.006       5.654
# scale(pickup_latitude)     -57.5679      4.487    -12.829      0.000     -66.363     -48.773
# scale(pickup_longitude)    -34.0346      8.089     -4.208      0.000     -49.888     -18.181
# scale(dropoff_longitude)    50.8802      7.894      6.446      0.000      35.409      66.351
# ================================================================================
# Omnibus:                  8314034.686   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322728224630796.500
# Skew:                         347.638   Prob(JB):                           0.00
# Kurtosis:                  195494.292   Cond. No.                           650.
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## 모든 실수 변수에 scale

# %%
model = sm.OLS.from_formula("scale(trip_duration) ~ scale(distance) + scale(bearing) + scale(pickup_hour) + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     scale(trip_duration)   R-squared:                       0.010
# Model:                              OLS   Adj. R-squared:                  0.010
# Method:                   Least Squares   F-statistic:                     2008.
# Date:                  Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                          23:33:10   Log-Likelihood:            -2.0627e+06
# No. Observations:               1458644   AIC:                         4.125e+06
# Df Residuals:                   1458636   BIC:                         4.126e+06
# Df Model:                             7
# Covariance Type:              nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0209      0.001    -17.334      0.000      -0.023      -0.019
# C(vendor_id)[T.2]            0.0392      0.002     23.698      0.000       0.036       0.042
# scale(distance)              0.0924      0.001    105.069      0.000       0.091       0.094
# scale(bearing)               0.0080      0.001      8.538      0.000       0.006       0.010
# scale(pickup_hour)           0.0053      0.001      6.409      0.000       0.004       0.007
# scale(pickup_latitude)      -0.0110      0.001    -12.829      0.000      -0.013      -0.009
# scale(pickup_longitude)     -0.0065      0.002     -4.208      0.000      -0.010      -0.003
# scale(dropoff_longitude)     0.0097      0.002      6.446      0.000       0.007       0.013
# ================================================================================
# Omnibus:                  8314034.686   Durbin-Watson:                     2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   2322728224630789.000
# Skew:                         347.638   Prob(JB):                           0.00
# Kurtosis:                  195494.292   Cond. No.                           3.54
# ================================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## log(trip_duration + 1)

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ scale(distance) + scale(bearing) + scale(pickup_hour) + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.339
# Model:                                 OLS   Adj. R-squared:                  0.339
# Method:                      Least Squares   F-statistic:                 1.067e+05
# Date:                     Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                             23:35:23   Log-Likelihood:            -1.4349e+06
# No. Observations:                  1458644   AIC:                         2.870e+06
# Df Residuals:                      1458636   BIC:                         2.870e+06
# Df Model:                                7
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    6.4539      0.001   8213.465      0.000       6.452       6.455
# C(vendor_id)[T.2]            0.0244      0.001     22.682      0.000       0.022       0.026
# scale(distance)              0.4667      0.001    815.921      0.000       0.466       0.468
# scale(bearing)               0.0475      0.001     78.081      0.000       0.046       0.049
# scale(pickup_hour)           0.0415      0.001     77.401      0.000       0.040       0.043
# scale(pickup_latitude)      -0.0270      0.001    -48.384      0.000      -0.028      -0.026
# scale(pickup_longitude)     -0.1167      0.001   -116.187      0.000      -0.119      -0.115
# scale(dropoff_longitude)     0.0959      0.001     97.890      0.000       0.094       0.098
# ==============================================================================
# Omnibus:                  2385607.366   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     113646943192.050
# Skew:                          -9.399   Prob(JB):                         0.00
# Kurtosis:                    1370.316   Cond. No.                         3.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## log(trip_duration+1), log(distance+1)

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + bearing + scale(pickup_hour) + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.572
# Model:                                 OLS   Adj. R-squared:                  0.572
# Method:                      Least Squares   F-statistic:                 2.789e+05
# Date:                     Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                             23:37:10   Log-Likelihood:            -1.1169e+06
# No. Observations:                  1458644   AIC:                         2.234e+06
# Df Residuals:                      1458636   BIC:                         2.234e+06
# Df Model:                                7
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    5.1442      0.001   3836.516      0.000       5.142       5.147
# C(vendor_id)[T.2]            0.0217      0.001     25.158      0.000       0.020       0.023
# np.log1p(distance)           0.9722      0.001   1351.599      0.000       0.971       0.974
# bearing                      0.0006    4.7e-06    126.822      0.000       0.001       0.001
# scale(pickup_hour)           0.0424      0.000     98.253      0.000       0.042       0.043
# scale(pickup_latitude)       0.0026      0.000      5.821      0.000       0.002       0.003
# scale(pickup_longitude)     -0.0703      0.001    -88.604      0.000      -0.072      -0.069
# scale(dropoff_longitude)     0.0255      0.001     32.551      0.000       0.024       0.027
# ==============================================================================
# Omnibus:                   440594.769   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         44478218.381
# Skew:                           0.441   Prob(JB):                         0.00
# Kurtosis:                      30.038   Cond. No.                         657.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## log(trip_duration+1), log(distance+1), sin(pickup_hour)

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + bearing + np.sin(pickup_hour) + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())

# %% [markdown]
# ## log(trip_duration+1), log(distance+1), sin(pickup_hour), sin(bearing)

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance) + np.sin(bearing) + np.sin(pickup_hour) + scale(pickup_latitude) + scale(pickup_longitude) +"
                            "scale(dropoff_longitude) + C(vendor_id)", train)
result = model.fit()
print(result.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.565
# Model:                                 OLS   Adj. R-squared:                  0.565
# Method:                      Least Squares   F-statistic:                 2.708e+05
# Date:                     Mon, 12 Mar 2018   Prob (F-statistic):               0.00
# Time:                             23:39:49   Log-Likelihood:            -1.1291e+06
# No. Observations:                  1458644   AIC:                         2.258e+06
# Df Residuals:                      1458636   BIC:                         2.258e+06
# Df Model:                                7
# Covariance Type:                 nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    5.2441      0.001   4732.624      0.000       5.242       5.246
# C(vendor_id)[T.2]            0.0223      0.001     25.604      0.000       0.021       0.024
# np.log1p(distance)           0.9661      0.001   1334.060      0.000       0.965       0.968
# np.sin(bearing)           9.185e-05      0.001      0.150      0.881      -0.001       0.001
# np.sin(pickup_hour)         -0.0168      0.001    -26.866      0.000      -0.018      -0.016
# scale(pickup_latitude)       0.0078      0.000     17.342      0.000       0.007       0.009
# scale(pickup_longitude)     -0.0207      0.001    -29.231      0.000      -0.022      -0.019
# scale(dropoff_longitude)    -0.0219      0.001    -30.949      0.000      -0.023      -0.021
# ==============================================================================
# Omnibus:                   416044.508   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         33674538.338
# Skew:                           0.415   Prob(JB):                         0.00
# Kurtosis:                      26.524   Cond. No.                         5.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
train2 = train.copy()

# %%
def bearing_array2(lat1, lng1, lat2, lng2):
    lng_delta_rad = np.radians(lng2 - lng1)
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    y = np.sin(lng_delta_rad) * np.cos(lat2)
    x = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(lng_delta_rad)
    return np.degrees(np.arctan2(y, x))

# %%
lat1, lng1, lat2, lng2 = (train2['pickup_latitude'].values, train2['pickup_longitude'].values, 
                          train2['dropoff_latitude'].values, train2['dropoff_longitude'].values)

# %%
train2 = train.assign(bearing = bearing_array2(lat1, lng1, lat2, lng2))

# %%
train2.tail()
# Out:
#                 id  vendor_id     pickup_datetime    dropoff_datetime  \
# 1458639  id2376096          2 2016-04-08 13:31:04 2016-04-08 13:44:02
# 1458640  id1049543          1 2016-01-10 07:35:15 2016-01-10 07:46:10
# 1458641  id2304944          2 2016-04-22 06:57:41 2016-04-22 07:10:25
# 1458642  id2714485          1 2016-01-05 15:56:26 2016-01-05 16:02:39
# 1458643  id1209952          1 2016-04-05 14:44:25 2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# 1458639                4        -73.982201        40.745522
# 1458640                1        -74.000946        40.747379
# 1458641                1        -73.959129        40.768799
# 1458642                1        -73.982079        40.749062
# 1458643                1        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude  store_and_fwd_flag  \
# 1458639         -73.994911         40.740170                   0
# 1458640         -73.970184         40.796547                   0
# 1458641         -74.004433         40.707371                   0
# 1458642         -73.974632         40.757107                   0
# 1458643         -73.972809         40.790585                   0
#
#          trip_duration  pickup_month  pickup_weekday  pickup_hour  \
# 1458639            778             4               4           13
# 1458640            655             1               6            7
# 1458641            764             4               4            6
# 1458642            373             1               1           15
# 1458643            198             4               1           14
#
#          working_day  distance     bearing
# 1458639            1  1.225080 -119.059338
# 1458640            0  6.049836   25.342196
# 1458641            1  7.824606 -150.788492
# 1458642            1  1.092564   35.033294
# 1458643            1  1.134042   29.969486

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ scale(bearing) + scale(I(bearing ** 2)) + scale(I(bearing ** 3)) +"
                            "scale(I(bearing ** 4)) + scale(I(bearing ** 5))", train2)
result = model.fit()
print(result.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.005
# Model:                                 OLS   Adj. R-squared:                  0.005
# Method:                      Least Squares   F-statistic:                     1565.
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             00:14:48   Log-Likelihood:            -1.7326e+06
# No. Observations:                  1458644   AIC:                         3.465e+06
# Df Residuals:                      1458638   BIC:                         3.465e+06
# Df Model:                                5
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  6.4670      0.001   9841.366      0.000       6.466       6.468
# scale(bearing)            -0.1614      0.003    -50.533      0.000      -0.168      -0.155
# scale(I(bearing ** 2))     0.1505      0.003     58.584      0.000       0.145       0.156
# scale(I(bearing ** 3))     0.4304      0.008     52.635      0.000       0.414       0.446
# scale(I(bearing ** 4))    -0.1273      0.003    -50.000      0.000      -0.132      -0.122
# scale(I(bearing ** 5))    -0.2651      0.006    -46.679      0.000      -0.276      -0.254
# ==============================================================================
# Omnibus:                   151387.902   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           930440.405
# Skew:                          -0.309   Prob(JB):                         0.00
# Kurtosis:                       6.864   Cond. No.                         27.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result2 = model.fit_regularized(alpha=0.01, L1_wt=0.5)
print(result2.params)
print(result2.summary())
# Out:
# Intercept          6.361488e+00
# bearing           -2.260954e-04
# I(bearing ** 2)    6.674292e-06
# I(bearing ** 3)    1.886252e-08
# I(bearing ** 4)    0.000000e+00
# I(bearing ** 5)    0.000000e+00
# dtype: float64
# None

# %%
model = sm.OLS.from_formula("scale(np.log1p(trip_duration)) ~ scale(np.log1p(distance))"
                            "+ scale(I(pickup_hour ** 2)) + scale(I(pickup_hour ** 4)) + scale(bearing)", train)
result = model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     scale(np.log1p(trip_duration))   R-squared:                       0.586
# Model:                                        OLS   Adj. R-squared:                  0.586
# Method:                             Least Squares   F-statistic:                 5.154e+05
# Date:                            Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                                    01:01:08   Log-Likelihood:            -1.4272e+06
# No. Observations:                         1458644   AIC:                         2.854e+06
# Df Residuals:                             1458639   BIC:                         2.854e+06
# Df Model:                                       4
# Covariance Type:                        nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                   5.302e-17      0.001   9.95e-14      1.000      -0.001       0.001
# scale(np.log1p(distance))      0.7651      0.001   1427.742      0.000       0.764       0.766
# scale(I(pickup_hour ** 2))     0.5109      0.002    261.310      0.000       0.507       0.515
# scale(I(pickup_hour ** 4))    -0.5145      0.002   -262.890      0.000      -0.518      -0.511
# scale(bearing)                 0.0520      0.001     97.423      0.000       0.051       0.053
# ==============================================================================
# Omnibus:                   402504.436   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15202446.098
# Skew:                           0.638   Prob(JB):                         0.00
# Kurtosis:                      18.764   Cond. No.                         7.20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
train_X0.head()
# Out:
#           id  vendor_id     pickup_datetime    dropoff_datetime  \
# 0  id2875421          2 2016-03-14 17:24:55 2016-03-14 17:32:30
# 1  id2377394          1 2016-06-12 00:43:35 2016-06-12 00:54:38
# 2  id3858529          2 2016-01-19 11:35:24 2016-01-19 12:10:48
# 3  id3504673          2 2016-04-06 19:32:31 2016-04-06 19:39:40
# 4  id2181028          2 2016-03-26 13:30:55 2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude  store_and_fwd_flag  pickup_month  pickup_weekday  \
# 0         40.765602                   0             3               0
# 1         40.731152                   0             6               6
# 2         40.710087                   0             1               1
# 3         40.706718                   0             4               2
# 4         40.782520                   0             3               5
#
#    pickup_hour  working_day  distance     bearing
# 0           17            1  1.498521   99.970196
# 1            0            0  1.805507  242.846232
# 2           11            1  6.385098  200.319835
# 3           19            1  1.485498  187.262300
# 4           13            0  1.188588  179.473585

# %%
col_reals = col_real + ["pickup_hour", "pickup_weekday", "pickup_month"]
train_reals = train[col_reals]
train_reals.head()
# Out:
#    passenger_count  distance     bearing  pickup_longitude  pickup_latitude  \
# 0                1  1.498521   99.970196        -73.982155        40.767937
# 1                1  1.805507  242.846232        -73.980415        40.738564
# 2                1  6.385098  200.319835        -73.979027        40.763939
# 3                1  1.485498  187.262300        -74.010040        40.719971
# 4                1  1.188588  179.473585        -73.973053        40.793209
#
#    dropoff_longitude  dropoff_latitude  pickup_hour  pickup_weekday  \
# 0         -73.964630         40.765602           17               0
# 1         -73.999481         40.731152            0               6
# 2         -74.005333         40.710087           11               1
# 3         -74.012268         40.706718           19               2
# 4         -73.972923         40.782520           13               5
#
#    pickup_month
# 0             3
# 1             6
# 2             1
# 3             4
# 4             3

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(train_reals.values, i) for i in range(train_reals.shape[1])]
vif["features"] = train_reals.columns
vif
# Out:
#      VIF Factor           features
# 0  2.606391e+00    passenger_count
# 1  1.714442e+00           distance
# 2  4.411248e+00            bearing
# 3  3.819268e+06   pickup_longitude
# 4  1.815531e+06    pickup_latitude
# 5  3.590561e+06  dropoff_longitude
# 6  1.596748e+06   dropoff_latitude
# 7  5.578616e+00        pickup_hour
# 8  3.468770e+00     pickup_weekday
# 9  5.379472e+00       pickup_month

# %%
model = sm.OLS.from_formula("np.log1p(trip_duration) ~ np.log1p(distance)"
                            "+ np.sin(pickup_hour)", train)
result = model.fit()
print(result.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log1p(trip_duration)   R-squared:                       0.563
# Model:                                 OLS   Adj. R-squared:                  0.563
# Method:                      Least Squares   F-statistic:                 9.378e+05
# Date:                     Tue, 13 Mar 2018   Prob (F-statistic):               0.00
# Time:                             02:46:05   Log-Likelihood:            -1.1335e+06
# No. Observations:                  1458644   AIC:                         2.267e+06
# Df Residuals:                      1458641   BIC:                         2.267e+06
# Df Model:                                2
# Covariance Type:                 nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               5.2744      0.001   5406.149      0.000       5.273       5.276
# np.log1p(distance)      0.9515      0.001   1369.315      0.000       0.950       0.953
# np.sin(pickup_hour)    -0.0167      0.001    -26.600      0.000      -0.018      -0.015
# ==============================================================================
# Omnibus:                   368887.611   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12163127.499
# Skew:                           0.558   Prob(JB):                         0.00
# Kurtosis:                      17.103   Cond. No.                         4.52
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
